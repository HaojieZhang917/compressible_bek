# %%
include("LST_BEK.jl")
# Out:
# Main.eigvec_compute

# %%
include("LST_BEK.jl")
using Plots
using LinearAlgebra
using NonlinearEigenproblems

# %%
num = 1
c = 0.38
N = 99
omega = 0
beta = 0.07759
R = 285.36
Ro = 1
Co = 2
A0,A1,A2,A3,A4 = KEB_SpatialMode.KEB_LST_ALL("Vonkarmen.txt",N,omega,beta,R,Ro,Co)
nep = PEP([A0,A1,A2,A3,A4]); 
eigval,eigvec = iar(nep,σ = c , neigs = num ,maxit = 500,tol=1e-10)
eigval
# Out:
# 1-element Vector{ComplexF64}:
#  0.3849581024731942 + 7.635479062934991e-5im
