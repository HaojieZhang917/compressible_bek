# %%
include("LST_BEK.jl")
# Out:
# Main.io

# %%
## ori
using .KEB_TimeMode
using BSplineKit
using LinearAlgebra

# %%
N = 99
α = 0.38482
β = 0.07759 
Ro = 1
Co = 2
R = 286
baseflow = "Vonkarmen.txt"
A,B,A11,A12,A21,A22,B11,B12,B21,B22= KEB_TimeMode.KEB_LST_all(baseflow,N,α,β,R,Ro,Co)
# Out:
# (ComplexF64[-33343.0749970986 + 4.048727591130886e10im 15867.82469131086 - 1.2535248162893328e10im … 0.4533724138721559 + 0.0im -0.4530297168490379 + 0.0im; 23330.883360566415 - 1.242948333945936e10im -31859.76912308735 + 9.181615772696758e9im … -0.4513383667869221 + 0.0im 0.45099677721974635 + 0.0im; … ; -1.4215784574178953e-6 - 0.0im 1.4233717828323053e-6 - 0.0im … 0.0 - 0.15414233839140118im 0.0 + 3.431140519835604e-5im; 8.882613319072109e-8 - 0.0im -8.893810281263769e-8 - 0.0im … 0.0 + 2.171397400353659e-6im 0.0 - 0.15410879774242864im], ComplexF64[-5.1455888671168484e7 + 0.38482im 2.440758357159813e7 - 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 1.5989261793655042e7 - 0.0im -2.190867890085483e7 + 0.38482im … 0.0 + 0.0im 0.0 + 0.0im; … ; 0.0 + 0.0im 0.0 + 0.0im … 286.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 286.0 + 0.0im], ComplexF64[-1671.0834504102038 + 4.184084819439877e11im 2830.1671403964024 - 7.661924245940104e11im … -1.8111522709183 + 1.516013773388423e9im 0.90534
# ...

# %%
A11
# Out:
# 100×100 Matrix{ComplexF64}:
#     -1671.08+4.18408e11im   …     0.905345-7.57805e8im
#      27896.8+2.62259e11im         -2.38951-3.60191e8im
#     -7093.69+4.68226e10im          2.57759+1.47699e7im
#      3140.92-4.91822e9im           -2.8091-2.52233e6im
#     -1751.31+9.21622e8im           3.11228+7.14422e5im
#      1108.24-2.46146e8im    …     -3.48115-2.60039e5im
#     -760.017+8.29203e7im           3.90405+1.09074e5im
#      551.333-3.28768e7im          -4.36668-49682.7im
#     -417.174+1.47047e7im           4.85317+23626.3im
#       326.41-7.21645e6im          -5.34668-11358.8im
#             ⋮               ⋱
#  -1.08659e-6+2.56079im          5.74506e-6-0.253451im
#   6.48512e-7-1.50429im         -3.38262e-6+0.151742im
#  -3.55495e-7+0.813521im         1.83291e-6-0.0833946im
#   1.73671e-7-0.392966im        -8.86818e-7+0.0408262im
#  -7.18872e-8+0.161178im     …   3.64215e-7-0.0169271im
#   2.29311e-8-0.0510526im       -1.15481e-7+0.00540632im
# ...

# %%
@show B
# Out:
# 194×194 Matrix{ComplexF64}:
#  -5.14559e7+0.38482im   2.44076e7-0.0im      …    0.0+0.0im    0.0+0.0im
#   1.59893e7-0.0im      -2.19087e7+0.38482im       0.0+0.0im    0.0+0.0im
#  -2.61474e6-0.0im       8.40652e6-0.0im           0.0+0.0im    0.0+0.0im
#   8.29392e5-0.0im      -1.51475e6-0.0im           0.0+0.0im    0.0+0.0im
#  -3.51926e5-0.0im       5.14333e5-0.0im           0.0+0.0im    0.0+0.0im
#   1.76881e5-0.0im      -2.30063e5-0.0im      …    0.0+0.0im    0.0+0.0im
#    -99595.2-0.0im       1.20747e5-0.0im           0.0+0.0im    0.0+0.0im
#     60952.3-0.0im        -70551.3-0.0im           0.0+0.0im    0.0+0.0im
#    -39812.8-0.0im         44608.4-0.0im           0.0+0.0im    0.0+0.0im
#     27427.9-0.0im        -30006.4-0.0im           0.0+0.0im    0.0+0.0im
#            ⋮                                 ⋱
#         0.0+0.0im             0.0+0.0im      …    0.0+0.0im    0.0+0.0im
#         0.0+0.0im             0.0+0.0im           0.0+0.0im    0.0+0.0im
# ...

# %%
c = eigen(A,B)
va = c.values
# Out:
# 194-element Vector{ComplexF64}:
#  -0.07673495540722627 - 0.0025280237730474684im
#  -0.07591687613281575 - 0.0032660902045178724im
#  -0.07534083032714405 - 0.005298163617240835im
#  -0.07428516346025746 - 0.006702676411721487im
#  -0.07366929574581019 - 0.009035536044330056im
#  -0.07226845117856051 - 0.010956436081371567im
#  -0.07176875599696547 - 0.013532606915631072im
#  -0.07014869718221332 - 0.015939118749329417im
#  -0.06964364563414605 - 0.018783361783315185im
#  -0.06773196459888504 - 0.02159268226049474im
#                       ⋮
#  0.027523494346275837 - 9.388567083136792im
#  0.027894556069980165 - 8.478962228003203im
#   0.02795772997557878 - 5.147105595740147im
#  0.028669282002041024 - 7.9471899817333735im
#  0.028748324373420866 - 5.4908180687490535im
#   0.02895735299371178 - 5.889660256166251im
#   0.02900302629216424 - 6.221359493342233im
#   0.02911180274651623 - 7.354536786283031im
#   0.02913363924786978 - 6.806273657156221im
